# %%
import os
import json
import pandas as pd
import numpy as np
import tqdm

from collections import defaultdict

from surprise import SVD
from surprise import Dataset
from surprise import Reader

DATA_PATH = './data/'

# %matplotlib inline

# %%
from scipy.sparse import coo_matrix, csr_matrix

# %%
with open(os.path.join(DATA_PATH, 'test_users.json'), 'r') as f:
    test_users = set(str(x) for x in json.load(f)['users'])

# %%
# %%time
transactions = pd.read_csv(
    os.path.join(DATA_PATH, 'transactions.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'consumption_mode': 'category',
        'ts': np.float64,
        'watched_time': np.uint64,
        'device_type': np.uint8,
        'device_manufacturer': np.uint8
    }
)
# Out:
# CPU times: user 7.06 s, sys: 412 ms, total: 7.47 s
# Wall time: 7.88 s

# %%
# %%time
ratings = pd.read_csv(
    os.path.join(DATA_PATH, 'ratings.csv'),
    dtype={
        'element_uid': np.object,
        'user_uid': np.object,
        'ts': np.float64,
        'rating': np.float64
    }
)
# Out:
# CPU times: user 322 ms, sys: 8.47 ms, total: 331 ms
# Wall time: 338 ms

# %%
ratings.head()
# Out:
#   user_uid element_uid  rating            ts
# 0   571252        1364    10.0  4.430517e+07
# 1    63140        3037    10.0  4.430514e+07
# 2   443817        4363     8.0  4.430514e+07
# 3   359870        1364    10.0  4.430506e+07
# 4   359870        3578     9.0  4.430506e+07

# %%
ratings.shape
# Out:
# (438790, 4)

# %%
ratings.dtypes
# Out:
# user_uid        object
# element_uid     object
# rating         float64
# ts             float64
# dtype: object

# %%
# %%time

# A reader is still needed but only the rating_scale param is requiered.
#reader = Reader(rating_scale=(0, 10))
reader = Reader(line_format='user item rating timestamp', sep='\t')

# The columns must correspond to user id, item id and ratings (in that order).
#data = Dataset.load_from_df(ratings[['user_uid', 'element_uid', 'rating']], reader)
data = Dataset.load_from_file('ratings_for_surprise.csv', reader=reader)

trainset = data.build_full_trainset()
algo = SVD(random_state = 42)
algo.fit(trainset)
# Out:
# CPU times: user 43.4 s, sys: 69.6 ms, total: 43.5 s
# Wall time: 43.6 s

# %%
from surprise.model_selection.validation import cross_validate
from surprise.model_selection.search import GridSearchCV

param_grid = {'n_factors':[3, 10, 20], 
              'n_epochs': [10, 30, 50],
              'lr_all': [0.001, 0.01], 
              'reg_all': [0.01, 0.3]
             }
gs = GridSearchCV(SVD, param_grid, cv=3, n_jobs=3, joblib_verbose=1)
gs.fit(data)
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=3)]: Done 108 out of 108 | elapsed: 27.1min finished

# %%
print(gs.best_score['rmse'])
print(gs.best_score['mae'])

print(gs.best_params['rmse'])
print(gs.best_params['mae'])
# Out:
# 1.8121488224837197
# 1.3492190145100131
# {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 30, 'n_factors': 3}
# {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 30, 'n_factors': 3}

# %%
results_df = pd.DataFrame.from_dict(gs.cv_results)
results_df
# Out:
#     mean_fit_time  mean_test_mae  mean_test_rmse  mean_test_time  \
# 0        2.939929       1.442987        1.893394        2.091502
# 1        3.484743       1.443101        1.893552        2.048743
# 2        4.258252       1.443462        1.893943        2.027107
# 3       12.723315       1.393608        1.847700        3.873046
# 4       13.935749       1.394309        1.848475        3.475496
# 5       21.598279       1.395377        1.849779        3.072328
# 6       21.807308       1.372470        1.829914        3.103650
# 7       39.551223       1.375008        1.833723        4.137668
# 8       50.591306       1.379225        1.838906        4.015861
# 9        6.073208       1.369325        1.846220        3.408165
# 10       3.942424       1.381103        1.861949        2.474564
# 11       4.907319       1.386544        1.867381        2.407463
# 12      11.298491       1.434116        1.981538        3.734212
# 13      14.083563       1.457719        1.995701        3.061303
# 14      23.348731       1.442783        1.959281        4.229337
# 15      23.229110       1.460156        2.036696        4.025179
# 16      38.433153       1.490873        2.045748        4.375328
# 17      49.480384       1.460455        1.982801        4.547884
# 18       6.896049       1.459695        1.902088        3.436310
# 19       4.101585       1.459815        1.902240        2.661623
# 20       4.823517       1.459846        1.902283        2.424460
# 21      10.751337       1.414925        1.857827        3.022033
# 22      13.908592       1.415029        1.857909        2.961706
# 23      19.434689       1.415277        1.858157        3.996695
# 24      27.451941       1.394207        1.838330        3.300553
# 25      44.561671       1.394284        1.838413        4.516816
# 26      47.466558       1.394564        1.838631        4.463061
# 27       7.217274       1.369837        1.817562        4.699626
# 28       4.962474       1.370093        1.817814        3.052331
# 29       6.009013       1.370361        1.818055        2.817338
# 30      16.862468       1.349219        1.812149        4.514054
# 31      17.139166       1.350672        1.814218        4.172995
# 32      27.422076       1.352192        1.815861        5.097960
# 33      26.566821       1.356193        1.836032        4.126644
# 34      34.028800       1.358518        1.837002        4.022652
# 35      40.972521       1.358487        1.833991        3.290961
#
#     param_lr_all  param_n_epochs  param_n_factors  param_reg_all  \
# 0          0.001              10                3           0.01
# 1          0.001              10               10           0.01
# 2          0.001              10               20           0.01
# 3          0.001              30                3           0.01
# 4          0.001              30               10           0.01
# 5          0.001              30               20           0.01
# 6          0.001              50                3           0.01
# 7          0.001              50               10           0.01
# 8          0.001              50               20           0.01
# 9          0.010              10                3           0.01
# 10         0.010              10               10           0.01
# 11         0.010              10               20           0.01
# 12         0.010              30                3           0.01
# 13         0.010              30               10           0.01
# 14         0.010              30               20           0.01
# 15         0.010              50                3           0.01
# 16         0.010              50               10           0.01
# 17         0.010              50               20           0.01
# 18         0.001              10                3           0.30
# 19         0.001              10               10           0.30
# 20         0.001              10               20           0.30
# 21         0.001              30                3           0.30
# 22         0.001              30               10           0.30
# 23         0.001              30               20           0.30
# 24         0.001              50                3           0.30
# 25         0.001              50               10           0.30
# 26         0.001              50               20           0.30
# 27         0.010              10                3           0.30
# 28         0.010              10               10           0.30
# 29         0.010              10               20           0.30
# 30         0.010              30                3           0.30
# 31         0.010              30               10           0.30
# 32         0.010              30               20           0.30
# 33         0.010              50                3           0.30
# 34         0.010              50               10           0.30
# 35         0.010              50               20           0.30
#
#                                                params  rank_test_mae  ...  \
# 0   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             27  ...
# 1   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             28  ...
# 2   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             29  ...
# 3   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             16  ...
# 4   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             19  ...
# 5   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             21  ...
# 6   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             11  ...
# 7   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             12  ...
# 8   {'reg_all': 0.01, 'lr_all': 0.001, 'n_epochs':...             13  ...
# 9   {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...              7  ...
# 10  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             14  ...
# 11  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             15  ...
# 12  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             25  ...
# 13  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             30  ...
# 14  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             26  ...
# 15  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             34  ...
# 16  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             36  ...
# 17  {'reg_all': 0.01, 'lr_all': 0.01, 'n_epochs': ...             35  ...
# 18  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             31  ...
# 19  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             32  ...
# 20  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             33  ...
# 21  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             22  ...
# 22  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             23  ...
# 23  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             24  ...
# 24  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             17  ...
# 25  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             18  ...
# 26  {'reg_all': 0.3, 'lr_all': 0.001, 'n_epochs': ...             20  ...
# 27  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 1...              8  ...
# 28  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 1...              9  ...
# 29  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 1...             10  ...
# 30  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 3...              1  ...
# 31  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 3...              2  ...
# 32  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 3...              3  ...
# 33  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 5...              4  ...
# 34  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 5...              6  ...
# 35  {'reg_all': 0.3, 'lr_all': 0.01, 'n_epochs': 5...              5  ...
#
#     split0_test_mae  split0_test_rmse  split1_test_mae  split1_test_rmse  \
# 0          1.445809          1.898325         1.441832          1.889576
# 1          1.445830          1.898418         1.441905          1.889720
# 2          1.446228          1.898862         1.442360          1.890189
# 3          1.396592          1.852856         1.392762          1.844165
# 4          1.397356          1.853801         1.393380          1.844840
# 5          1.398548          1.855182         1.394306          1.846035
# 6          1.374688          1.834163         1.371895          1.826524
# 7          1.377836          1.839173         1.374014          1.829371
# 8          1.382005          1.843999         1.379442          1.835932
# 9          1.374443          1.853921         1.367348          1.841186
# 10         1.384757          1.867134         1.380244          1.858664
# 11         1.387787          1.869802         1.387915          1.866348
# 12         1.432048          1.979336         1.438385          1.983600
# 13         1.460544          1.999450         1.457733          1.991139
# 14         1.442341          1.959259         1.444936          1.960332
# 15         1.464149          2.042885         1.458991          2.031280
# 16         1.490522          2.045457         1.494655          2.047404
# 17         1.460966          1.985729         1.462011          1.982601
# 18         1.462098          1.906454         1.459011          1.899103
# 19         1.462218          1.906565         1.459130          1.899301
# 20         1.462284          1.906693         1.459158          1.899343
# 21         1.417568          1.862308         1.414297          1.854967
# 22         1.417685          1.862388         1.414387          1.855072
# 23         1.417920          1.862642         1.414617          1.855275
# 24         1.396579          1.842678         1.393791          1.835642
# 25         1.396652          1.842762         1.393803          1.835634
# 26         1.396934          1.843017         1.394162          1.835934
# 27         1.372552          1.821808         1.370634          1.815782
# 28         1.372773          1.822030         1.370826          1.815939
# 29         1.373098          1.822330         1.371072          1.816156
# 30         1.350671          1.814803         1.351199          1.811996
# 31         1.352527          1.817370         1.352109          1.813185
# 32         1.353881          1.819016         1.353500          1.814664
# 33         1.357594          1.838568         1.357679          1.834954
# 34         1.359248          1.838941         1.359972          1.835998
# 35         1.359666          1.836659         1.360007          1.833450
#
#     split2_test_mae  split2_test_rmse  std_fit_time  std_test_mae  \
# 0          1.441320          1.892282      0.119275      0.002006
# 1          1.441567          1.892517      0.160395      0.001935
# 2          1.441798          1.892778      0.126091      0.001969
# 3          1.391470          1.846081      0.651710      0.002175
# 4          1.392190          1.846783      3.832739      0.002209
# 5          1.393276          1.848120      4.823715      0.002282
# 6          1.370826          1.829054      5.528891      0.001628
# 7          1.373174          1.832626      6.801442      0.002029
# 8          1.376228          1.836787      2.172353      0.002364
# 9          1.366184          1.843553      2.073764      0.003650
# 10         1.378307          1.860049      0.261168      0.002702
# 11         1.383931          1.865995      0.373301      0.001849
# 12         1.431916          1.981678      1.244355      0.003019
# 13         1.454879          1.996515      1.147495      0.002313
# 14         1.441072          1.958252      1.310829      0.001608
# 15         1.457329          2.035923      3.525524      0.002904
# 16         1.487441          2.044382      8.436424      0.002955
# 17         1.458387          1.980072      3.861971      0.001523
# 18         1.457976          1.900708      2.077028      0.001751
# 19         1.458096          1.900853      0.172626      0.001751
# 20         1.458097          1.900812      0.738244      0.001777
# 21         1.412910          1.856206      0.249944      0.001953
# 22         1.413015          1.856267      0.709755      0.001959
# 23         1.413293          1.856553      1.592163      0.001946
# 24         1.392252          1.836669      1.029085      0.001791
# 25         1.392398          1.836842      1.832672      0.001770
# 26         1.392598          1.836942      5.451276      0.001793
# 27         1.366326          1.815097      1.468331      0.002604
# 28         1.366680          1.815471      0.350940      0.002541
# 29         1.366913          1.815679      1.004383      0.002575
# 30         1.345786          1.809648      1.909875      0.002437
# 31         1.347379          1.812099      0.584654      0.002334
# 32         1.349195          1.813902      3.763776      0.002125
# 33         1.353307          1.834573      0.900707      0.002041
# 34         1.356335          1.836067      0.694072      0.001572
# 35         1.355788          1.831866      7.845971      0.001914
#
#     std_test_rmse  std_test_time
# 0        0.003657       0.037592
# 1        0.003625       0.035298
# 2        0.003635       0.027138
# 3        0.003728       0.116138
# 4        0.003849       0.867926
# 5        0.003914       0.856226
# 6        0.003177       0.854887
# 7        0.004076       0.278305
# 8        0.003618       0.968572
# 9        0.005530       1.333342
# 10       0.003710       0.083227
# 11       0.001717       0.132245
# 12       0.001743       0.904732
# 13       0.003441       0.504397
# 14       0.000849       0.304073
# 15       0.004769       0.731550
# 16       0.001251       1.065004
# 17       0.002314       0.144791
# 18       0.003156       1.069119
# 19       0.003123       0.228957
# 20       0.003176       0.242179
# 21       0.003209       0.675504
# 22       0.003205       0.579265
# 23       0.003214       1.059186
# 24       0.003103       0.914515
# 25       0.003115       0.299956
# 26       0.003129       0.138590
# 27       0.003015       1.099243
# 28       0.002988       0.289386
# 29       0.003029       0.245791
# 30       0.002107       1.267425
# 31       0.002273       0.609509
# 32       0.002253       0.754167
# 33       0.001800       0.355778
# 34       0.001371       0.797409
# 35       0.001994       0.735855
#
# [36 rows x 21 columns]

# %%
#default 
'test_mae': array([1.38723197, 1.39241735, 1.38574688]),
'test_rmse': array([1.85676068, 1.86323958, 1.85731211]),
# Out:
# 20

# %%
ratings_users = set(ratings.user_uid.unique())
test_users_with_ratings = list(test_users & ratings_users)

# %%
movie_list = list(ratings.element_uid.unique())

# %%
top_n = defaultdict(list)
n = 500

for uid in ['571252', '63140', '443817', '359870']:

    #tqdm.tqdm(test_users_with_ratings):

    # First map the predictions to each user.
    user_ratings = [(iid, algo.predict(uid, iid, verbose=False)[3]) for iid in movie_list]
    
    # Then sort the predictions for each user and retrieve the k highest ones.
    user_ratings.sort(key=lambda x: x[1], reverse=True)
    top_n[uid] = user_ratings[:n]
# Out:
# 100%|██████████| 13251/13251 [32:37<00:00,  5.93it/s]

# %%
#['571252', '63140', '443817', '359870']:
    
    
algo.predict('571252', '1364', verbose=False)[3]
#9.442963984462768
#algo.predict('63140', '1364', verbose=False)[3]
#8.878428447496999
#algo.predict('443817', '1364', verbose=False)[3]
#8.704440941004862
#algo.predict('359870', '1364', verbose=False)[3]
#9.895491469075125
# Out:
# 5

# %%
from collections import defaultdict

filtered_elements = defaultdict(set)

for user_uid, element_uid in tqdm.tqdm(transactions.loc[:, ['user_uid', 'element_uid']].values):
    if user_uid not in test_users:
        continue
    filtered_elements[user_uid].add(element_uid)
# Out:
# 100%|██████████| 9643012/9643012 [00:18<00:00, 531231.45it/s]

# %%
result = {}
for user_uid in tqdm.tqdm(test_users_with_ratings):
    result[user_uid] = [int(x) for x, _ in top_n[user_uid] if x not in filtered_elements[user_uid]][:20]
# Out:
# 100%|██████████| 13251/13251 [00:03<00:00, 4362.38it/s]

# %%
with open('./predictions/svd_surprise_strings.json', 'w') as f:
    json.dump(result, f)
